# %%
import json
import os

import pandas as pd
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm
import concurrent.futures

# %%
pd.set_option('display.max_rows', None)

# %%
# df = pd.read_csv('data/players_15.csv')
df = pd.read_csv('../data/FIFA22_official_data.csv')

# %%
player_names = list(df["Name"])
# escapes = ''.join([chr(char) for char in range(1, 32)])

# escapes = ''.join([chr(char) for char in range(1, 32)])
# translator = str.maketrans('', '', escapes)


player_names = [player for player in player_names]

# %%
print(str(player_names))
# Out:
# ['Bruno Fernandes', 'L. Goretzka', 'L. Suárez', 'K. De Bruyne', 'M. Acuña', 'J. Kimmich', 'Paulinho', 'G. Wijnaldum', 'E. Can', 'A. Griezmann', 'L. Modrić', 'Marcos Llorente', 'Sergio Ramos', 'D. Alaba', 'Merino', 'N. Barella', 'Alex Telles', 'F. de Jong', 'M. Sabitzer', 'J. Cuadrado', 'Koke', 'João Cancelo', 'L. Digne', 'F. Kostić', 'T. Alexander-Arnold', 'S. Milinković-Savić', 'A. Vidal', 'P. Pogba', 'Casemiro', 'L. Messi', 'Renato Sanches', 'L. Ocampos', 'Jordi Alba', 'R. Lewandowski', 'M. Salah', 'Angeliño', 'Cristiano Ronaldo', '12\xa0Roberto Carlos', 'Canales', 'H. Kane', '19\xa0Dani Alves', 'M. Brozović', 'M. Verratti', 'Saúl', 'Thiago', 'J. Veretout', 'J. Henderson', 'I. Gündoğan', 'R. Nainggolan', 'T. Delaney', 'Lucas Paquetá', 'F. Kessié', 'R. Malinovskyi', 'K. Walker', 'R. Gosens', 'S. Mané', 'L. Pellegrini', 'D. Wass', 'A. Hakimi', 'Y. Tielemans', 'Ricardo Pereira', 'T. Hernández', 'Grimaldo', '21\xa0Renato Augusto', 'Neymar Jr', 'K. Trippier', 'N. De la Cruz', '12\xa0M. Ballack', 'Roberto Firmino', '19\xa0C. Marchisio', 'R. De Paul', 'N. Kanté', 'A. Florenzi', 'Yuri Berchiche', 'G. Bale', 'Portu', 'A. Di María', '21\xa0I. Fernández', 'Jesús Navas', 'F. Valverde', 'R. Guerreiro', 'L. Paredes', 'K. Mbappé', 'G. Lo Celso', '19\xa0D. Srna', 'A. Kolarov', 'Fred', 'Carlos Soler', '19\xa0C. Noboa', 'Rúben Neves', 'Anderson Talisca', 'J. Corona', 'Parejo', 'C. Tolisso', 'A. Witsel', 'Raúl García', 'Fabinho', 'A. Robertson', 'T. Partey', 'L. Robertone', 'L. Provod', 'Renan Lodi', 'M. Arnold', '17\xa0J. Vargas', 'I. Bennacer', 'E. Banega', 'H. Herrera', 'Marcelo', 'W. McKennie', 'T. Lemar', 'I. Perišić', 'Arthur', '17\xa0S. Gerrard', 'Capa', 'P. Ševčík', 'Oscar', 'T. Kroos', 'F. Mendy', 'Alex Sandro', 'Diogo Jota', 'L. Stindl', 'M. Pjanić', 'J. Tavernier', 'O. Zinchenko', 'Pizzi', '17\xa0P. Lahm', 'H. Mkhitaryan', 'M. Rashford', 'L. Martínez', 'H. Son', 'D. van de Beek', 'T. Koopmeiners', 'J. Milner', '19\xa0Filipe Luís', 'Sérgio Oliveira', 'A. Golovin', 'Z. Junuzović', '20\xa0T. Vilhena', 'M. Hamšík', 'J. Ward-Prowse', 'C. Aránguiz', 'Ander Herrera', 'Fernandinho', 'M. Uribe', 'G. Bonaventura', 'G. Kondogbia', 'Lucas Vázquez', '16\xa0Michel Bastos', 'K. Laimer', '16\xa0Maicon', 'T. Müller', '17\xa0B. Trémoulinas', 'A. Rabiot', '16\xa0Raúl Meireles', 'J. Vardy', 'J. Kucka', 'P. Dybala', 'T. Savanier', 'Campaña', '21\xa0Hulk', 'Adryan Zonta', 'Jorginho', 'Jonathan Viera', 'Gerson', 'I. Rakitić', 'Marcos Alonso', 'Allan', 'L. Shaw', 'R. Vormer', '21\xa0Santi Cazorla', 'Bernardo Silva', 'C. Erkin', 'Danilo', 'A. Correa', 'C. Nkunku', 'M. Reus', 'João Moutinho', 'D. Caligiuri', 'K. Volland', 'B. Bourigeaud', 'M. Kovačić', 'Juan Bernat', 'Richarlison', 'D. Klaassen', 'Carvajal', 'Rafinha', 'E. Bardhi', 'A. Oxlade-Chamberlain', 'M. Casco', 'M. Dembélé', 'O. Trejo', 'R. Karsdorp', 'B. André', '19\xa0Ramires', 'Morales', 'K. Boateng', 'Gerard Moreno', 'T. Ndombele', 'M. de Roon', 'N. Fekir', 'R. Pereyra', 'K. Benzema', 'M. Sanson', '18\xa0Gabi', 'N. Stanciu', 'G. Moreno', 'D. Alli', 'H. Aouar', 'P. Zieliński', 'M. Antonio', 'A. Davies', 'Fabián', '17\xa0Maxwell', 'E. Pérez', '19\xa0Y. Rakitskyi', 'M. Locatelli', '18\xa0Eliseu', 'M. Arnautović', 'W. Ndidi', 'Álex Berenguer', 'R. Sterling', 'P. Max', 'A. Guardado', 'G. Di Lorenzo', 'Gabriel', 'M. Camara', 'L. Spinazzola', '21\xa0Wendel', 'A. Claude-Maurice', 'T. Souček', 'D. Tadić', 'R. Delgado', 'W. Ben Yedder', 'R. Skov', 'Cucurella', '19\xa0F. Guarín', 'J. McGinn', 'M. Faraoni', 'R. Rodríguez', 'M. Wakaso', 'Y. Bissouma', 'V. van Dijk', 'Ai Kesen', 'Gedson Fernandes', '15\xa0Xavi', 'K. Demirbay', 'S. McTominay', 'I. Gueye', 'D. Suárez', '19\xa0Jefferson', 'Embarba', 'E. Haaland', 'A. Silva', 'T. Holeš', 'Gerson Armão', 'A. Rebić', 'L. Advíncula', 'M. Cornet', 'R. Bentancur', 'M. Mount', 'Melvin Parrela', 'Raphinha', 'L. Torreira', 'R. James', 'Ronaldo Cabrais', 'Rodri', 'D. Blind', 'Gayà', 'E. Salvio', 'R. Baku', 'R. Tapia', 'Mário Fernandes', 'Andreas Pereira', 'U. Račić', 'Pedro ...
